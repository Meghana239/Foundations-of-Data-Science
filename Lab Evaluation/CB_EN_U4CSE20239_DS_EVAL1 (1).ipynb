# %% [markdown]
# Q1

# %%
import pandas as pd
df = pd.read_csv('/content/Absenteeism_at_work.csv',sep='[;]')
df
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py:311: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   return func(*args, **kwargs)
#      ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0    11                  26                 7                3        1
# 1    36                   0                 7                3        1
# 2     3                  23                 7                4        1
# 3     7                   7                 7                5        1
# 4    11                  23                 7                5        1
# ..   ..                 ...               ...              ...      ...
# 735  11                  14                 7                3        1
# ...

# %% [markdown]
# Q2

# %%
df.dropna(inplace=True)
df
# Out:
#      ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0    11                  26                 7                3        1
# 1    36                   0                 7                3        1
# 2     3                  23                 7                4        1
# 3     7                   7                 7                5        1
# 4    11                  23                 7                5        1
# ..   ..                 ...               ...              ...      ...
# 735  11                  14                 7                3        1
# 736   1                  11                 7                3        1
# 737   4                   0                 0                3        1
# 738   8                   0                 0                4        2
# 739  35                   0                 0                6        3
#
#      Transportation expense  Distance from Residence to Work  Service time  \
# ...

# %% [markdown]
# Q4

# %%
boxplot = df.boxplot(column=['Age'])

# %%
boxplot = df.boxplot(column=['Transportation expense'])

# %% [markdown]
# Q5

# %%
print(df['Age'].corr(df['Month of absence']))
# Out:
# -0.0015195444984268014

# %% [markdown]
# Q6

# %%
df.describe()
# Out:
#                ID  Reason for absence  Month of absence  Day of the week  \
# count  740.000000          740.000000        740.000000       740.000000
# mean    18.017568           19.216216          6.324324         3.914865
# std     11.021247            8.433406          3.436287         1.421675
# min      1.000000            0.000000          0.000000         2.000000
# 25%      9.000000           13.000000          3.000000         3.000000
# 50%     18.000000           23.000000          6.000000         4.000000
# 75%     28.000000           26.000000          9.000000         5.000000
# max     36.000000           28.000000         12.000000         6.000000
#
#           Seasons  Transportation expense  Distance from Residence to Work  \
# count  740.000000              740.000000                       740.000000
# mean     2.544595              221.329730                        29.631081
# std      1.111831               66.952223                        14.836788
# ...

# %% [markdown]
# Q7

# %%
df.head(3)
# Out:
#    ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0  11                  26                 7                3        1
# 1  36                   0                 7                3        1
# 2   3                  23                 7                4        1
#
#    Transportation expense  Distance from Residence to Work  Service time  Age  \
# 0                     289                               36            13   33
# 1                     118                               13            18   50
# 2                     179                               51            18   38
#
#    Work load Average/day   ...  Disciplinary failure  Education  Son  \
# 0                 239.554  ...                     0          1    2
# 1                 239.554  ...                     1          1    1
# 2                 239.554  ...                     0          1    0
#
#    Social drinker  Social smoker  Pet  Weight  Height  Body mass index  \
# ...

# %% [markdown]
# Q8

# %%
df.tail(4)
# Out:
#      ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 736   1                  11                 7                3        1
# 737   4                   0                 0                3        1
# 738   8                   0                 0                4        2
# 739  35                   0                 0                6        3
#
#      Transportation expense  Distance from Residence to Work  Service time  \
# 736                     235                               11            14
# 737                     118                               14            13
# 738                     231                               35            14
# 739                     179                               45            14
#
#      Age  Work load Average/day   ...  Disciplinary failure  Education  Son  \
# 736   37                 264.604  ...                     0          3    1
# ...

# %% [markdown]
# Q9

# %%
print(df.iloc[239])
# Out:
# ID                                  34.000
# Reason for absence                  26.000
# Month of absence                     7.000
# Day of the week                      6.000
# Seasons                              1.000
# Transportation expense             118.000
# Distance from Residence to Work     10.000
# Service time                        10.000
# Age                                 37.000
# Work load Average/day              275.312
# Hit target                          98.000
# Disciplinary failure                 0.000
# Education                            1.000
# Son                                  0.000
# Social drinker                       0.000
# Social smoker                        0.000
# Pet                                  0.000
# Weight                              83.000
# Height                             172.000
# Body mass index                     28.000
# Absenteeism time in hours            4.000
# Name: 239, dtype: float64

# %% [markdown]
# Q10

# %%
df.count()
# Out:
# ID                                 740
# Reason for absence                 740
# Month of absence                   740
# Day of the week                    740
# Seasons                            740
# Transportation expense             740
# Distance from Residence to Work    740
# Service time                       740
# Age                                740
# Work load Average/day              740
# Hit target                         740
# Disciplinary failure               740
# Education                          740
# Son                                740
# Social drinker                     740
# Social smoker                      740
# Pet                                740
# Weight                             740
# Height                             740
# Body mass index                    740
# Absenteeism time in hours          740
# dtype: int64

# %% [markdown]
# 11.	Display the first 5 columns of the first row

# %%
print(df.iloc[0:1,0:5])
# Out:
#    ID  Reason for absence  Month of absence  Day of the week  Seasons
# 0  11                  26                 7                3        1

# %% [markdown]
# 13.	Split people according to their body mass index into two groups: overweight (25 to 30) and obese (>30).

# %%
bmi1 = df.loc[df.Body mass index == ">25 and <30"]
print(bmi1)
bmi2 = df.loc[df.Body mass index == ">30"]
print(bmi2)
# Out:
#   File "<ipython-input-43-de39d0fefee5>", line 1
#     bmi1 = df.loc[df.Body mass index == ">25 and <30"]
#                              ^
# SyntaxError: invalid syntax

# %% [markdown]
# 15.	Compute the mean and the variance of "transportation expenses” for medical consultations

# %%
print(df['Transportation expense'].mean())
print(df['Transportation expense'].var())
# Out:
# 221.32972972972973
# 4482.600197491131
